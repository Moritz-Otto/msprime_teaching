# %% [markdown]
# # TMRCA and Bottlenecks

# %% [markdown]
# Import dependencies

# %%
import msprime
from IPython.display import SVG, display

# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Parameters

# %%
n = 30
N = 1e4

T1 = 1000
N1 = 500
T2 = 2000
N2 = 2000

demographic_events = [
    msprime.PopulationParametersChange(time=T1,initial_size=N1),
    msprime.PopulationParametersChange(time=T2,initial_size=N2),
]
ts = msprime.simulate(n,Ne=N, demographic_events=demographic_events)
tree = ts.first()
tree.draw_svg(y_axis=True,size=(600,800))
# Out:
# '<svg baseProfile="full" height="800" version="1.1" width="600" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><style type="text/css"><![CDATA[.background path {fill: #808080; fill-opacity: 0}.background path:nth-child(odd) {fill-opacity: .1}.x-regions rect {fill: yellow; stroke: black; opacity: 0.5}.axes {font-size: 14px}.x-axis .tick .lab {font-weight: bold; dominant-baseline: hanging}.axes, .tree {font-size: 14px; text-anchor: middle}.axes line, .edge {stroke: black; fill: none}.axes .ax-skip {stroke-dasharray: 4}.y-axis .grid {stroke: #FAFAFA}.node > .sym {fill: black; stroke: none}.site > .sym {stroke: black}.mut text {fill: red; font-style: italic}.mut.extra text {fill: hotpink}.mut line {fill: none; stroke: none}.mut .sym {fill: none; stroke: red}.mut.extra .sym {stroke: hotpink}.node .mut .sym {stroke-width: 1.5px}.tree text, .tree-sequence text {dominant-baseline: central}.plotbox .lab.lft {text-anchor: end}.plotbox .lab.rgt {text-anchor: start}.polytomy line {stroke: black; stroke-dasharray: 1px, 1px}.polytomy text {paint-order:stroke;stroke-width:0.3em;stroke:white}]]></style></defs><g class="tree t0"><g class="axes"><g class="y-axis"><g class="title" transform="translate(0 389.1)"><text class="lab" text-anchor="middle" transform="translate(11) rotate(-90)">Time ago (generations)</text></g><line class="ax-line" x1="56.8" x2="56.8" y1="768.2" y2="10"/><g class="ticks"><g class="tick" transform="translate(56.8 768.2)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">0.00</text></g></g><g class="tick" transform="translate(56.8 753.656)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">87.32</text></g></g><g class="tick" transform="translate(56.8 750.818)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">104.36</text></g></g><g class="tick" transform="translate(56.8 746.665)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">129.29</text></g></g><g class="tick" transform="translate(56.8 712.379)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">335.13</text></g></g><g class="tick" transform="translate(56.8 706.227)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">372.06</text></g></g><g class="tick" transform="translate(56.8 692.453)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">454.76</text></g></g><g class="tick" transform="translate(56.8 691.328)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">461.51</text></g></g><g class="tick" transform="translate(56.8 683.182)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">510.42</text></g></g><g class="tick" transform="translate(56.8 682.103)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">516.90</text></g></g><g class="tick" transform="translate(56.8 672.058)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">577.20</text></g></g><g class="tick" transform="translate(56.8 670.949)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">583.86</text></g></g><g class="tick" transform="translate(56.8 663.92)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">626.06</text></g></g><g class="tick" transform="translate(56.8 644.708)"><line x1="0" x2="-5" y1="0" y2="0"/><g transform="translate(-6 0)"><text class="lab" text-anchor="end">741.40</text></g></g><g class="tick" transform="translate(56.8 633.422)"><line x ...

# %% [markdown]
# ## 10,000 simulations

# %%
n = 30
N = 1e4

T1 = 4000
N1 = 1500
T2 = 6500
N2 = 5000
demographic_events = [
    msprime.PopulationParametersChange(time=T1,initial_size=N1),
    msprime.PopulationParametersChange(time=T2,initial_size=N2),
]

pw_tmrca = []

for _ in tqdm(range(int(3e3))):
    ts = msprime.simulate(n, Ne=N, demographic_events=demographic_events)
    tree = ts.first()
    pw_tmrca.append(tree.tmrca(0, 1))

pw_tmrca = np.array(pw_tmrca)
# Out:
# 100%|████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 463.33it/s]

# %% [markdown]
# Plot

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10))

x = np.sort(pw_tmrca)
y = np.arange(1, len(x) + 1) / len(x)
ax1.step(x, y, where="post",lw=3)
ax1.set_xlim(0,4*N)
ax1.axvline(x=T1, color='red', linestyle='--')
ax1.axvline(x=T2, color='red', linestyle='--')

times = [0, T1, T2, 4*N]
Pop_size = [N, N1, N2, N2]
ax2.step(times, Pop_size, where="post",lw=3)
ax2.set_xlim(0,4*N)
ax2.set_ylim(0,max(N,N1,N2)*1.1)
ax2.axvline(x=T1, color='red', linestyle='--')
ax2.axvline(x=T2, color='red', linestyle='--')

plt.show()
